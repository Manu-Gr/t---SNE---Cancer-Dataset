# %% [markdown]
# <a href="https://colab.research.google.com/github/Manu-Gr/t---SNE---Diabetes-Dataset/blob/main/t_Distributed_Stochastic_Neighbor_Embedding_(t_SNE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**t-Distributed Stochastic Neighbor Embedding (t-SNE)**

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.manifold import TSNE
from bioinfokit.visuz import cluster

# %%
pip install bioinfokit  # if needed install this package

# %%
# load dataset

cancer = pd.read_csv('TSNE_data.csv')
cancer
# Out:
#     diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0           M        17.99  ...          0.4601                  0.11890
# 1           M        20.57  ...          0.2750                  0.08902
# 2           M        19.69  ...          0.3613                  0.08758
# 3           M        11.42  ...          0.6638                  0.17300
# 4           M        20.29  ...          0.2364                  0.07678
# ..        ...          ...  ...             ...                      ...
# 564         M        21.56  ...          0.2060                  0.07115
# 565         M        20.13  ...          0.2572                  0.06637
# 566         M        16.60  ...          0.2218                  0.07820
# 567         M        20.60  ...          0.4087                  0.12400
# 568         B         7.76  ...          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
# Convert data to array format
cancer_ary=cancer.values
cancer_ary
# Out:
# array([['M', 17.99, 10.38, ..., 0.2654, 0.4601, 0.1189],
#        ['M', 20.57, 17.77, ..., 0.18600000000000003, 0.275, 0.08902],
#        ['M', 19.69, 21.25, ..., 0.243, 0.3613, 0.08757999999999999],
#        ...,
#        ['M', 16.6, 28.08, ..., 0.1418, 0.2218, 0.0782],
#        ['M', 20.6, 29.33, ..., 0.265, 0.4087, 0.124],
#        ['B', 7.76, 24.54, ..., 0.0, 0.2871, 0.07039]], dtype=object)

# %%
# Seperate array into input and output components

X = cancer_ary[:,1:]
Y = cancer_ary[:,0]

# %% [markdown]
# ###**t-SNE Implementation**

# %%
np.random.seed(42)
rndperm = np.random.permutation(df.shape[0])

# %%
tsne=TSNE(n_components=2)
cancer_tsne=tsne.fit_transform(X)
cancer_tsne
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# array([[-27.71716  , -18.272133 ],
#        [-30.157724 , -16.938597 ],
#        [-28.48873  , -12.30377  ],
#        ...,
#        [-21.298523 ,   5.477536 ],
#        [-28.81464  , -15.163312 ],
#        [  6.5835533, -31.528816 ]], dtype=float32)

# %%
# get a list of categories
color_class = dataframe['diagnosis'].to_numpy()
cluster.tsneplot(score=data_tsne, colorlist=color_class, legendpos='upper right',legendanchor=(1.15, 1))

#Plot will be stored in the default directory

# %%
data_tsne
# Out:
# array([[-31.33276   ,   0.77734834],
#        [-32.825317  ,  -1.5387886 ],
#        [-29.005718  ,  -4.7174287 ],
#        ...,
#        [-14.203772  , -16.209663  ],
#        [-30.847395  ,  -2.452333  ],
#        [-11.561627  ,  34.450466  ]], dtype=float32)

# %% [markdown]
# ![tsne_2d.png](data:image/png;base64,...)
